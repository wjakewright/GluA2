# %% [markdown]
# # GluA2 Analysis Pipeline

# %%
# Import relevant packages
import os
import numpy as np

from analyze_images import analyze_mean_lifetime, analyze_pixel_lifetime
from qupath_utils import load_analyzed_data
import plotting

# %%
# Trained ids
trained_mice = ["JJ002", "JJ003", "JJ006", "JJ007", "JJ009", "JJ011", "JJ012", "JJ013"] # No data for 7
trained_mice = ["JJ002", "JJ003", "JJ006", "JJ009", "JJ011", "JJ012", "JJ013"] 
#trained_mice = ["JJ002", "JJ003", "JJ006", "JJ009", "JJ011"]

# Untrained id
untrained_mice = ["JJ004", "JJ005", "JJ008", "JJ010", "JJ014", "JJ015"]
#untrained_mice = ["JJ004", "JJ005", "JJ008", "JJ010"] 
untrained_mice = ["JJ004", "JJ005", "JJ010", "JJ014", "JJ015"]

# %% [markdown]
# ## Analyze image data

# %%
# Average data
## Trained mice
analyze_mean_lifetime(trained_mice, save=True)

## Untrained mice
analyze_mean_lifetime(untrained_mice, save=True)
# Out:
# - Analyzing Mouse JJ002
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# - Analyzing Mouse JJ003
# - Analyzing Mouse JJ006
# - Analyzing Mouse JJ009
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# - Analyzing Mouse JJ011
# - Analyzing Mouse JJ012
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# - Analyzing Mouse JJ013
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# - Analyzing Mouse JJ004
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# C:\Users\Jake\Documents\Anaconda3\envs\GluA2\lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# - Analyzing Mouse JJ005
# - Analyzing Mouse JJ010
# - Analyzing Mouse JJ014
# - Analyzing Mouse JJ015

# %%
# Pixel data
analyze_pixel_lifetime(["JJ002"], modality="lifetime", save=True)

# %% [markdown]
# ## Plot the data

# %%
# Load in the analyzed data
trained_data = load_analyzed_data(trained_mice)
untrained_data = load_analyzed_data(untrained_mice)

# %%
figure_path = r"C:\Users\Jake\Desktop\Figures"

# %%
# Plot the raw life time data
plotting.compare_raw_lifetimes(
    untrained_data,
    trained_data,
    figsize=(20,50),
    display_stats=False,
    save=True,
    save_path=figure_path,
)
# Out:
# C:\Users\Jake\Desktop\python_code\GluA2\GluA2\plotting.py:1013: RuntimeWarning: Mean of empty slice
#   roi_data = np.nanmean(roi_data)

# %%
# Plot the relative life time data
plotting.compare_relative_lifetimes(
    untrained_data,
    trained_data,
    figsize=(15,50),
    display_stats=False,
    save=False,
    save_path=None,
)

# %%
a = np.array([50, 90, 80])

100 - a

# %%
area = "PVH"

trained_values = {}
untrained_values = {}

for i, data in enumerate(trained_data):
    v = data.loc[data["roi_name"] == area, "mean_lifetime"]
    animal = trained_mice[i]
    trained_values[animal] = np.nanmean(v)

for i, data in enumerate(untrained_data):
    v = data.loc[data["roi_name"] == area, "mean_lifetime"]
    print(v)
    animal = untrained_mice[i]
    untrained_values[animal] = np.nanmean(v)

# %%
names = trained_data[0]["roi_name"]

# %%
for n in names:
    print(n)

# %%
import numpy as np

np.absolute(3 / np.log(1 / np.nan))

# %%
np.array([1]) / np.array([0])
